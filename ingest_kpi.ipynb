# %%
from sqlalchemy import create_engine
import pandas as pd

URL = "postgresql://postgres:dotcep-demjak-qosmI6@database-sphere.chvqqqs41kgo.eu-central-1.rds.amazonaws.com/sphere"
engine = create_engine(URL, echo=True)

# %%
def read_csv(file_path):
    return pd.read_csv(file_path)

# %%
def write_to_db(df, table_name):
    df.to_sql(table_name, con=engine, if_exists='append', index=False)

# %%
import os

directory = 'raw_data/kpi'

for filename in os.listdir(directory):
    file_path = os.path.join(directory, filename)
    if os.path.isfile(file_path):
        print(f'Processing file: {file_path}')
        df = read_csv(file_path)
        df = df.iloc[1:].reset_index(drop=True)
        df.rename(columns={'cycle': 'cycle_id'}, inplace=True)
        write_to_db(df, 'KPI')
# Out:
# Processing file: raw_data/kpi/BMW_LTF_2198_001_10SOC-Cycling_469_T35_03-02-2025_KPIs.csv
# 2025-03-10 16:32:52,486 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-10 16:32:52,487 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-03-10 16:32:52,487 INFO sqlalchemy.engine.Engine [cached since 82.59s ago] {'table_name': 'KPI', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# ...

# %%
from models.widget_type import WidgetType

widget_type = WidgetType(name='Metadata')
df = pd.DataFrame([widget_type.__dict__])
df.to_sql('WIDGET_TYPE', con=engine, if_exists='append', index=False)
# Out:
# 2025-03-17 14:24:05,924 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-17 14:24:05,925 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-03-17 14:24:05,925 INFO sqlalchemy.engine.Engine [cached since 43s ago] {'table_name': 'WIDGET_TYPE', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-03-17 14:24:05,953 INFO sqlalchemy.engine.Engine INSERT INTO "WIDGET_TYPE" (_sa_instance_state, name) VALUES (%(_sa_instance_state)s, %(name)s)
# ...
